# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithyaanil121/report/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
students=['Alice','Bob','Carol','David','Eve']
math=np.array([85,72,91,60,88])
science=np.array([90,68,95,74,85])
english=np.array([78,88,82,70,92])

# %%
print("maths avg=",np.mean(math))
print("science avg=",np.mean(science))
print("top scorer=",np.max(math))
# Out:
# maths avg= 79.2
# science avg= 82.4
# top scorer= 91

# %%
total=math+science+english
print('total:',total)
# Out:
# total: [253 228 268 204 265]

# %%
print("index of rank1:",np.argmax(math))
# Out:
# index of rank1: 2

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Untitled spreadsheet - student_scores.csv')
print(df.head())
print(df.shape)
# Out:
#   Student  Math  Science  English Grade
# 0   Alice    85       90       78     A
# 1     Bob    72       68       88     B
# 2   Carol    91       95       82     A
# 3   David    60       74       70     C
# 4     Eve    88       85       92     A
# (5, 5)

# %%
top=df[df['Grade'].isin(['A','A+'])]
print(top[['Student','Math']])
# Out:
#   Student  Math
# 0   Alice    85
# 2   Carol    91
# 4     Eve    88

# %%
print(df.describe())
# Out:
#             Math    Science    English
# count   5.000000   5.000000   5.000000
# mean   79.200000  82.400000  82.000000
# std    12.949903  11.193748   8.602325
# min    60.000000  68.000000  70.000000
# 25%    72.000000  74.000000  78.000000
# 50%    85.000000  85.000000  82.000000
# 75%    88.000000  90.000000  88.000000
# max    91.000000  95.000000  92.000000

# %%
import matplotlib.pyplot as plt

# %%
names=['Alice','Bob','Carol','David','Eve']
marks=[85,72,91,60,88]

# %%
plt.bar(names,marks)
plt.xlabel('Students')
plt.ylabel('Marks')
plt.title('Marks of Students')
plt.grid(axis='y',alpha=0.4)
plt.show()

# %%
pd.read_csv('/content/Iris (1).csv')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.bar(Species,PetalLengthCm	)
plt.xlabel('Species')
plt.ylabel('PetalLengthCm	')
plt.title('species classifier')
plt.grid(axis='y',alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3237/4211757314.py in <cell line: 0>()
# ----> 1 plt.bar(Species,PetalLengthCm   )
#       2 plt.xlabel('Species')
#       3 plt.ylabel('PetalLengthCm       ')
#       4 plt.title('species classifier')
#       5 plt.grid(axis='y',alpha=0.4)
#
# NameError: name 'Species' is not defined
